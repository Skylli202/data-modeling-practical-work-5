# %%
import requests
import urllib

# %%
def get_prefixe():
    prefixes = 'prefix got: <http://www.got.org/esirem#> prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>'
    return prefixes

def get_headers():
    return {"Content-Type": "application/x-www-form-urlencoded", "Accept": "application/sparql-result+json"}

def parse_query(query):
    query = urllib.parse.unquote(query)
    query = urllib.parse.quote(query, safe="")
    return query

# %%
url = 'http://localhost:8080/api/query?query='

query = get_prefixe() + """
select distinct ?episode ?personnage
where {
    # ?episode got:contient_le_personnage ?personnage
}
order by ?episode
"""

url = url + parse_query(query)
r = requests.get(url, headers=get_headers())
print("Query: \n" + query)
print("URL : \n" + url)
print("\nResponse: \n" + json.loads(r.content.decode()))
# Out:
# Query:
# prefix got: <http://www.got.org/esirem#> prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# select distinct ?episode ?personnage
# where {
#     ?episode got:contient_le_personnage ?personnage
# }
# order by ?episode
#
# URL :
# http://localhost:8080/api/query?query=prefix%20got%3A%20%3Chttp%3A%2F%2Fwww.got.org%2Fesirem%23%3E%20prefix%20rdf%3A%20%3Chttp%3A%2F%2Fwww.w3.org%2F1999%2F02%2F22-rdf-syntax-ns%23%3E%0Aselect%20distinct%20%3Fepisode%20%3Fpersonnage%0Awhere%20%7B%0A%20%20%20%20%3Fepisode%20got%3Acontient_le_personnage%20%3Fpersonnage%0A%7D%0Aorder%20by%20%3Fepisode%0A
#
# Response:
# {
#   "head": {
#     "vars": [
#       "episode",
#       "personnage"
#     ]
#   },
#   "results": {
#     "bindings": [
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_1"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Eddard_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_1"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Robert_Baratheon"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_13"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Catelyn_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_15"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Joffrey_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_16"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Joffrey_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_17"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Joffrey_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_17"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_18"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Catelyn_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_19"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Cersei_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_20"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Joffrey_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_20"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_21"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_22"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_23"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Catelyn_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_24"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Cersei_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_26"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_28"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_29"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Catelyn_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_32"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Joffrey_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_33"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_35"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Cersei_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_35"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_38"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_4"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Eddard_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_41"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Cersei_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_43"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_44"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Cersei_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_45"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_46"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_47"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Cersei_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_47"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_48"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Cersei_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_48"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_5"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Catelyn_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_5"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Eddard_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_5"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Robert_Baratheon"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_50"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Cersei_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_51"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Cersei_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_51"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_52"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Cersei_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_54"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Cersei_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_54"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_55"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_57"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_58"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Cersei_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_59"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_6"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Eddard_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_6"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Robert_Baratheon"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_60"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Cersei_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_61"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Cersei_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_62"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Cersei_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_63"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Cersei_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_63"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_65"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Cersei_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_67"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Sansa_Stark"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_68"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Cersei_Lannister"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_7"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Robert_Baratheon"
#         }
#       },
#       {
#         "episode": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Episode_8"
#         },
#         "personnage": {
#           "type": "uri",
#           "value": "http://www.got.org/esirem#Eddard_Stark"
#         }
#       }
#     ]
#   }
# }
